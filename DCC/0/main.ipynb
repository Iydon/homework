# %% [markdown]
# Warm-up Project For Distributed Computing Concepts
# ===
#
# The goal is to reproduce following results:
#
# - $\min_u||u-f||_2^2+\lambda ||\nabla u||_1$
# - $\min_u||u-f||_2^2+\lambda ||u||_2^2$
# - $\min_u||u-f||_2^2+\lambda ||\nabla u||_2^2$

# %% [markdown]
# ## 0x01 Import necessary packages

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from model import Denoising

# %% [markdown]
# ## 0x02 Inialize noised image and *Denoising* model

# %%
nx, ny = 200, 200

I = 100 * np.ones((nx, ny))
I[75:150, 75:150] = 150
J = np.random.normal(0, 12, I.shape) + I

d = Denoising(J)
d.show(raw=I, cmap=plt.cm.gray)

# %% [markdown]
# ## 0x03 Reproduce the results

# %%
algorithms = ('Tikhonov', )

d.show(algorithms, cmap=plt.cm.gray)

# %%
algorithms = ('TN', )
d.show(algorithms, cmap=plt.cm.gray)

# %%
algorithms = ('TV', 'TNV', 'TGV')
d.show(algorithms, row=2, cmap=plt.cm.gray)
